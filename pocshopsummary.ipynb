# %% [markdown]
# **Based on the dataset and the notebook**
#
# Regression Hypothesis
#
# Target: price (numeric column)
#
# Question: Can we predict the price of a clothing item based on its attributes?
#
# Features used: category, colour, location, model photography, price_2, page, etc.
#
# Classification Hypothesis
#
# Target: page 1 (main category) (values: 1=trousers, 2=skirts, 3=blouses, 4=sale)
#
# Question: Can we predict which main category a product belongs to based on browsing/product attributes?
#
# Features used: colour, location, model photography, price, price_2, page, etc.
